# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuhin092005/Python/blob/main/Python_Strings_%26_Conditional_Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# we can define a string in various way

str1 = 'Tuhin'
print(str1)
str2 = "Tuhin"
print(str2)
str3 = """Tuhin"""
print(str3)
# Out:
# Tuhin
# Tuhin
# Tuhin

# %%
str = "Hello Tuhin Maji.\nWelcome to Python Lab."
print(str)
str = "Hello Tuhin Maji.\tWelcome to Python Lab."
print(str)
# Out:
# Hello Tuhin Maji.
# Welcome to Python Lab.
# Hello Tuhin Maji.	Welcome to Python Lab.

# %%
# Concatenation

str1 = "Tuhin"
str2 = "Maji"
str3 = str1 + str2
print(str3)
# Out:
# TuhinMaji

# %%
str1 = "Tuhin"
str2 = "Maji"
str3 = str1 + " " + str2
print(str3)
# Out:
# Tuhin Maji

# %%
# Length of a string

str = "Tuhin"
length = len(str)
print(length)

# %%
# Length function also calculate the empty space " "

str1 = "Tuhin"
str2 = " Maji"
str3 = str1 + str2
print(str3)
length = len(str3)
print(length)
# Out:
# Tuhin Maji
# 10

# %%
# Indexing
# Positive Indexing
# TuhinMaji
# 012345678
# Tuhin Maji
# 01234 5 6789 (Here index 5 is empty space )
# indexing also calculate the empty space

str = "Tuhin Maji"
ch = str[2:5]
print(ch)

str = "Tuhin Maji"
ch = str[2:6]
print(ch)

str = "Tuhin Maji"
ch = str[6:len(str)]
print(ch)

str = "Tuhin Maji"
ch = str[0:5]
print(ch)

# [:5] define as [0:5]

str = "Tuhin Maji"
ch = str[:5]
print(ch)

# [6:] define as [6:len(str)]

str = "Tuhin Maji"
ch = str[6:]
print(ch)
# Out:
# hin
# hin
# Maji
# Tuhin
# Tuhin
# Maji

# %%
# Slicing
# Negative Indexing
# Tuhin
# -5 -4 -3 -2 -1

str = "Tuhin"
ch = str[-5:-2]
print(ch)
# Out:
# Tuh

# %%
# String Functions

str = "I am a coder"

# returns true is the string ends with substring "er"
1. str.endswith("er")

# capitalize the 1st character
2. str.capitalize()

# replace the "coder" in the string with "developer"
3. str.replace(old, new)

# returns 1st index of 1st occurrences
4. str.find(word)

# count how many times the substring "am" occur in the string
5. str.count("am")

# %%
str = "i am a coder"

print(str.endswith("er"))

print(str.capitalize())

print(str.replace("coder", "developer"))

print(str.find("a"))

print(str.find("coder"))

# as "s" doesnot present in our string, it will return -1
print(str.find("s"))

print(str.count("am"))
# Out:
# True
# I am a coder
# i am a developer
# 2
# 7
# -1
# 1

# %%
# Conditional Statements syntax

if(condition1):
  print(statement1)
elif(condition2):
  print(statement2)
else:
  print(statement3)

# %%
num = 20
if(num > 0):
  print("Positive Number")
elif(num < 0):
  print("Negative Number")
else:
  print("NULL Value")
# Out:
# Positive Number

# %%
marks = int(input("Enter the marks of the student:"))
if(marks >= 90):
  print("Grade: A")
elif(marks>= 80 and marks < 90):
  print("Grade: B")
elif(marks>= 70 and marks < 80):
  print("Grade: C")
else:
  print("Grade: D")
# Out:
# Enter the marks of the student:85
# Grade: B

# %%
# nesting

if(condition1):
  if(condition2):
    print(statement)

# %%
age = 22

if(age >= 18):
  if(age >= 80):
    print("Can't Drive")
  else:
    print("Can Drive")
else:
  print("Can't Drive")
# Out:
# Can Drive

# %%
age = 93

if(age >= 18):
  if(age >= 80):
    print("Can't Drive")
  else:
    print("Can Drive")
else:
  print("Can't Drive")
# Out:
# Can't Drive

# %%
# check a number is Odd or Even

num = int(input("Enter a number:"))
if(num%2 == 0):
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number:5
# Odd

# %%
# Find the greatest number among three numbers

a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))

if(a>b):
  if(a>c):
    print(f"{a} is the greatest number")
  else:
    print(f"{c} is the greatest number")
else:
  if(b>c):
    print(f"{b} is the greatest number")
  else:
    print(f"{c} is the greatest number")
# Out:
# Enter the first number:2
# Enter the second number:3
# Enter the third number:4
# 4 is the greatest number

# %%
# Find the greatest number among three numbers

a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))

if(a>b):
  print(f"{a} is the greatest number")
elif(b>c):
  print(f"{b} is the greatest number")
else:
  print(f"{c} is the greatest number")
# Out:
# Enter the first number:2
# Enter the second number:3
# Enter the third number:4
# 4 is the greatest number

# %%
# check if a number is a multiple of 7 or not

num = int(input("Enter a number:"))

if(num%7 == 0):
  print(f"{num} is a multiple of 7")
else:
  print(f"{num} is not a multiple of 7")
# Out:
# Enter a number:8
# 8 is not a multiple of 7
